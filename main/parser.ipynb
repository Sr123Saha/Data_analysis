# %%
import cianparser

# Создаем экземпляр парсера
parser = cianparser.CianParser(location="Одинцово")

# Получаем данные
data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page":1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\josha\OneDrive\Documents\GitHub\1intensive1\main\cian_flat_sale_1_54_odintsovo_30_Oct_2024_12_23_10_330098.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
# 12
# 6
# 28 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: -1 rub
# 12
# 8
#
# 28 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 4 849 999 rub
# 12
# 8
#
# 14 | 1 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 6 683 332 rub
# 6
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 1 page...
#
#
# 30 page: 28 offers
# 12
# 8
#
#  2 page: 28 offers
# 14 page: 28 offers
# 6
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 2 page...
#
#
# 83 page: 28 offers
#
# 20 page: 28 offers
# 8
#
#  3 | 3 page with list: [=>                                                      ] 4% | Count of all parsed: 9. Progress ratio: 1 %. Average price: 16 181 310 rub
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 3 page...
#
#
# 16 | 4 page with list: [=>                                                      ] 4% | Count of all parsed: 10. Progress ratio: 1 %. Average price: 16 641 310 rub
# 8
#
#  4 | 4 page with list: [=>=>                                                    ] 8% | Count of all parsed: 11. Progress ratio: 1 %. Average price: 17 364 037 rub
# 18 | 4 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 12. Progress ratio: 1 %. Average price: 17 947 371 rub
# 8
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 4 page...
#
#
# 10 page: 28 offers
# 6
#
# 28 | 5 page with list: [=>                                                      ] 4% | Count of all parsed: 14. Progress ratio: 1 %. Average price: 19 166 510 rub
# 12
# 8
#
# 28 page: 28 offers
# 12
# 8
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 5 page...
#
#
#  6 page: 28 offers
# 86 page: 28 offers
#
# 46 | 6 page with list: [=>                                                      ] 4% | Count of all parsed: 18. Progress ratio: 2 %. Average price: 21 008 706 rub
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 6 page...
#
#
# 26 page: 28 offers
# 12
# 8
#
# 10 page: 28 offers
#
# 10 | 7 page with list: [=>                                                      ] 4% | Count of all parsed: 21. Progress ratio: 2 %. Average price: 22 255 418 rub
# 6
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 7 page...
#
#
# 10 page: 28 offers
# 6
#
#  8 | 8 page with list: [=>                                                      ] 4% | Count of all parsed: 23. Progress ratio: 2 %. Average price: 23 079 469 rub
# 10 | 8 page with list: [=>=>                                                    ] 8% | Count of all parsed: 24. Progress ratio: 2 %. Average price: 23 369 052 rub
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 8 page...
#
#
# 10 page: 28 offers
#
# 26 | 9 page with list: [=>                                                      ] 4% | Count of all parsed: 26. Progress ratio: 2 %. Average price: 24 162 898 rub
# 12
# 8
#
# 89 | 9 page with list: [=>=>                                                    ] 8% | Count of all parsed: 27. Progress ratio: 2 %. Average price: 24 466 602 rub
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 9 page...
#
#
# 240 page: 28 offers
# 12
# 8
#
# 300 | 10 page with list: [=>                                                      ] 4% | Count of all parsed: 29. Progress ratio: 2 %. Average price: 25 211 922 rub
# 12
# 8
#
# 280 page: 28 offers
# 12
# 8
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 10 page...
#
#
# 811 page: 28 offers
#
# 121 page: 28 offers
# 8
#
# 261 | 11 page with list: [=>                                                      ] 4% | Count of all parsed: 33. Progress ratio: 3 %. Average price: 26 306 757 rub
# 12
# 8
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 11 page...
#
#
# 242 page: 28 offers
# 8
#
# 122 | 12 page with list: [=>                                                      ] 4% | Count of all parsed: 35. Progress ratio: 3 %. Average price: 26 833 479 rub
# 8
#
# 102 | 12 page with list: [=>=>                                                    ] 8% | Count of all parsed: 36. Progress ratio: 3 %. Average price: 27 075 146 rub
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 12 page...
#
#
# 813 page: 28 offers
#
# 103 | 13 page with list: [=>                                                      ] 4% | Count of all parsed: 38. Progress ratio: 3 %. Average price: 27 659 428 rub
#
# 103 | 13 page with list: [=>=>                                                    ] 8% | Count of all parsed: 39. Progress ratio: 3 %. Average price: 27 938 915 rub
#
#
# Exception: dict contains fields not in fieldnames: 'price'
# The collection of information from the pages with ending parse on 13 page...
#
#
# 124 page: 28 offers
# 8
#
# 124 | 14 page with list: [=>                                                      ] 4% | Count of all parsed: 41. Progress ratio: 3 %. Average price: 28 366 171 rub
# 8
#
#  14 | 14 page with list: [=>=>                                                    ] 8% | Count of all parsed: 42. Progress ratio: 3 %. Average price: 28 554 266 rub
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 parser = cianparser.CianParser(location="Одинцово")
#       6 # Получаем данные
# ----> 7 data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page":1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
#
# File c:\Users\josha\OneDrive\Documents\GitHub\1intensive1\.venv\Lib\site-packages\cianparser\cianparser.py:119, in CianParser.get_flats(self, deal_type, rooms, with_saving_csv, with_extra_data, additional_settings)
#     108 deal_type, rent_period_type = __define_deal_type__(deal_type)
#     109 self.__parser__ = FlatListPageParser(
#     110     session=self.__session__,
#     111     accommodation_type="flat",
#    (...)
#     117     additional_settings=additional_settings,
#     118 )
# --> 119 self.__run__(
#     120     __build_url_list__(location_id=self.__location_id__, deal_type=deal_type, accommodation_type="flat",
#     121                        rooms=rooms, rent_period_type=rent_period_type,
#     122                        additional_settings=additional_settings))
#     123 return self.__parser__.result
#
# File c:\Users\josha\OneDrive\Documents\GitHub\1intensive1\.venv\Lib\site-packages\cianparser\cianparser.py:75, in CianParser.__run__(self, url_list_format)
#      73 while attempt_number_exception < 3 and not page_parsed:
#      74     try:
# ---> 75         (page_parsed, attempt_number, end_all_parsing) = self.__parser__.parse_list_offers_page(
#      76             html=self.__load_list_page__(url_list_format=url_list_format, page_number=page_number, attempt_number_exception=attempt_number_exception),
#      77             page_number=page_number,
#      78             count_of_pages=self.__parser__.end_page + 1 - self.__parser__.start_page,
#      79             attempt_number=attempt_number_exception)
#      81     except Exception as e:
#      82         attempt_number_exception += 1
#
# File c:\Users\josha\OneDrive\Documents\GitHub\1intensive1\.venv\Lib\site-packages\cianparser\flat\list.py:38, in FlatListPageParser.parse_list_offers_page(self, html, page_number, count_of_pages, attempt_number)
#      35     print(f"Collecting information from pages with list of offers", end="\n")
#      37 for ind, offer in enumerate(offers):
# ---> 38     self.parse_offer(offer=offer)
#      39     self.print_parse_progress(page_number=page_number, count_of_pages=count_of_pages, offers=offers, ind=ind)
#      41 time.sleep(2)
#
# File c:\Users\josha\OneDrive\Documents\GitHub\1intensive1\.venv\Lib\site-packages\cianparser\flat\list.py:63, in FlatListPageParser.parse_offer(self, offer)
#      61 if self.with_extra_data:
#      62     flat_parser = FlatPageParser(session=self.session, url=common_data["url"])
# ---> 63     page_data = flat_parser.parse_page()
#      64     time.sleep(4)
#      66 self.count_parsed_offers += 1
#
# File c:\Users\josha\OneDrive\Documents\GitHub\1intensive1\.venv\Lib\site-packages\cianparser\flat\page.py:116, in FlatPageParser.parse_page(self)
#     114 def parse_page(self):
#     115     self.__load_page__()
# --> 116     return self.__parse_flat_offer_page_json__()
#
# File c:\Users\josha\OneDrive\Documents\GitHub\1intensive1\.venv\Lib\site-packages\cianparser\flat\page.py:37, in FlatPageParser.__parse_flat_offer_page_json__(self)
#      35 ot = self.offer_page_soup.select_one('[data-name="OfferSummaryInfoItem"] p:nth-of-type(2)').get_text()
#      36 page_data["object_type"] = ot
# ---> 37 time.sleep(5 + random.uniform(0, 5))
#      39 pt_elements = self.offer_page_soup.select('[data-name="OfferSummaryInfoItem"] p')
#      40 for i, p_element in enumerate(pt_elements):
#
# KeyboardInterrupt:
