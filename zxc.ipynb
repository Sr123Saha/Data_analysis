# %%
import pandas as pd

df = pd.read_csv('zxc.csv')
df.columns = ['Город', 'тип сделки', 'тип недвижимости', 'этаж кв', 'высота дома в этажах', 'колво комнат', 'общая площадь квартиры', ' ', ' ', 'Цена', '', '', 'Дом', '', '', '', '', '', '', '']

df.head(11)
#df.describe(1)
# Out:
#      Город тип сделки тип недвижимости  этаж кв  высота дома в этажах  \
# 0   Москва       sale             flat       80                    85
# 1   Москва       sale             flat       26                    31
# 2   Москва       sale             flat        5                     9
# 3   Москва       sale             flat       10                    20
# 4   Москва       sale             flat       11                    12
# 5   Москва       sale             flat        5                    21
# 6   Москва       sale             flat        2                    10
# 7   Москва       sale             flat        3                     5
# 8   Москва       sale             flat       24                    42
# 9   Москва       sale             flat       11                    20
# 10  Москва       sale             flat        3                    24
#
#     колво комнат  общая площадь квартиры             Цена  \
# 0              4                  294.60 -1  0  412440000
# ...
