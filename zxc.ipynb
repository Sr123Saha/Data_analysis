# %%
import pandas as pd

df = pd.read_csv('zxc.csv')
df.columns = ['Город', 'тип сделки', 'тип недвижимости', 'этаж кв', 'высота дома в этажах', 'колво комнат', 'общая площадь квартиры', ' ', ' ', 'Цена', '', 'Улица', 'Дом', 'станция метро или жд', 'название жилого комплекса', '', '', '', '', '']
df.iloc[3088:3104]
#df.head(11)
#df.describe(1)
# Out:
#              Город тип сделки тип недвижимости  этаж кв  высота дома в этажах  \
# 3088  Долгопрудный       sale             flat        5                    23
# 3089  Долгопрудный       sale             flat        2                     9
# 3090  Долгопрудный       sale             flat       10                    17
# 3091  Долгопрудный       sale             flat        9                    25
# 3092  Долгопрудный       sale             flat       21                    23
# 3093  Долгопрудный       sale             flat       14                    25
# 3094  Долгопрудный       sale             flat        9                    23
# 3095  Долгопрудный       sale             flat        9                     9
# 3096  Долгопрудный       sale             flat       11                    13
# 3097  Долгопрудный       sale             flat        2                    18
# 3098  Долгопрудный       sale             flat       19                    25
# ...
