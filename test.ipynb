# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cdaaa.csv", sep=";")
df.head()
# Out:
#                author author_type  \
# 0  СЕТЬСТРОЙ БАЛАШИХА   developer
# 1          ID 7070788     realtor
# 2             Самолет   developer
# 3    Анастасия Тимина     realtor
# 4             Самолет   developer
#
#                                                url  location deal_type  \
# 0  https://balashikha.cian.ru/sale/flat/299327331/  Балашиха      sale
# 1  https://balashikha.cian.ru/sale/flat/301737579/  Балашиха      sale
# 2  https://balashikha.cian.ru/sale/flat/308722127/  Балашиха      sale
# 3  https://balashikha.cian.ru/sale/flat/302418386/  Балашиха      sale
# 4  https://balashikha.cian.ru/sale/flat/308661878/  Балашиха      sale
#
#   accommodation_type  floor  floors_count  rooms_count  total_meters  ...  \
# 0               flat      5            17            2         53.70  ...
# 1               flat      6            16            2         56.50  ...
# 2               flat     16            22            2         70.14  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                343 non-null    object
#  1   author_type           343 non-null    object
#  2   url                   395 non-null    object
#  3   location              395 non-null    object
#  4   deal_type             395 non-null    object
#  5   accommodation_type    395 non-null    object
#  6   floor                 395 non-null    int64
#  7   floors_count          395 non-null    int64
#  8   rooms_count           395 non-null    int64
#  9   total_meters          395 non-null    float64
#  10  price                 395 non-null    int64
#  11  year_of_construction  395 non-null    object
#  12  object_type           395 non-null    object
#  13  have_loggia           395 non-null    object
#  14  parking_type          395 non-null    object
# ...

# %%
df.shape
# Out:
# (395, 27)

# %%
df['total_meters'] = df['total_meters'].astype(int)
df['total_meters']
# Out:
# 0      53
# 1      56
# 2      70
# 3      58
# 4      59
#        ..
# 390    77
# 391    62
# 392    62
# 393    70
# 394    65
# Name: total_meters, Length: 395, dtype: object
